# %% [markdown]
# # *******************************************************************************************

# %% [markdown]
# # Problem Statement

# %% [markdown]
# ## A bike-sharing system wants to understand the factors affecting the demand for their shared bikes in the American market. The company wants to know :
#
# #### Which variables are significant in predicting the demand for shared bikes.
# #### How well those variables describe the bike demands

# %% [markdown]
# # Business Goal
# ### Design a model the demand for shared bikes with the available independent variables. It will be used by the management to understand how exactly the demands vary with different features. They can accordingly manipulate the business strategy to meet the demand levels and meet the customer's expectations. The model will be a good way for management to understand the demand dynamics of a new market.

# %% [markdown]
# # *******************************************************************************************

# %% [markdown]
# ## STEP 1:  Reading and Understanding the Data

# %% [markdown]
# #### Importing all the necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Read the data file

# %%
bike_day_data = pd.read_csv('day.csv')
bike_day_data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Statistical Descriptive analysis

# %%
bike_day_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
bike_day_data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
bike_day_data.shape
# Out:
# (730, 16)

# %% [markdown]
# ### Conclusion 1
#
# #### 1) Dataset has 16 columns and 730 rows
# #### 2) Column  dteday is an object
# #### 3) dteday ,Season , Year , Holiday , Week day, Month are categorical
# #### 4) Dependent Variable is cnt

# %% [markdown]
# # *******************************************************************************************

# %% [markdown]
# ## STEP 2: DATA ANALYSIS FOR NULL OR MISSING VALUES

# %%
bike_day_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
bike_day_data.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 725    0
# 726    0
# 727    0
# 728    0
# 729    0
# Length: 730, dtype: int64

# %% [markdown]
# ### Conclusion 2
# #### NO MISSING / NULL Values

# %% [markdown]
# # *******************************************************************************************

# %% [markdown]
# ## STEP 3: DATA CLEANING

# %% [markdown]
# ### REMOVE DUPLICATE ROWS

# %%
bike_day_data.drop_duplicates(subset=None,inplace=True)

# %%
bike_day_data.shape
# Out:
# (730, 16)

# %% [markdown]
# ### Conclusion 3
# #### No Duplicates in the Dataset

# %% [markdown]
# ### Checking any unknown values

# %%
bike_day_data.value_counts()
# Out:
# instant  dteday      season  yr  mnth  holiday  weekday  workingday  weathersit  temp       atemp     hum      windspeed  casual  registered  cnt
# 1        01-01-2018  1       0   1     0        6        0           2           14.110847  18.18125  80.5833  10.749882  331     654         985     1
# 480      25-04-2019  2       1   4     0        3        1           1           19.543347  23.51585  42.7917  7.959064   655     5541        6196    1
# 482      27-04-2019  2       1   4     0        5        1           1           18.757500  22.63185  40.0833  23.291411  1014    5219        6233    1
# 483      28-04-2019  2       1   4     0        6        0           2           15.443347  18.87520  48.9583  8.708325   1120    3100        4220    1
# 484      29-04-2019  2       1   4     0        0        0           1           18.791653  22.50605  58.7083  7.832836   2229    4075        6304    1
# ...

# %% [markdown]
# ### Conclusion 4
# #### No Unknown values found

# %% [markdown]
# ### Checking for unwanted columns

# %%
bike_day_data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
bike_day_data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### instant is not required since its an record index
# ### There is a seperate columns for date , month so dteday is not required

# %%
bike_data = bike_day_data[['season', 'yr', 'mnth', 'holiday', 'weekday',
       'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
       'casual', 'registered', 'cnt']]

# %%
bike_data.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed  casual  registered   cnt
# 0  18.18125  80.5833  10.749882     331         654   985
# 1  17.68695  69.6087  16.652113     131         670   801
# 2   9.47025  43.7273  16.636703     120        1229  1349
# 3  10.60610  59.0435  10.739832     108        1454  1562
# 4  11.46350  43.6957  12.522300      82        1518  1600

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  casual      730 non-null    int64
#  12  registered  730 non-null    int64
#  13  cnt         730 non-null    int64
# dtypes: float64(4), int64(10)
# memory usage: 85.5 KB

# %% [markdown]
# ### Since Season,Month, Weekday, Weathersit  are of type Categorical but in Dataset it has been defined as numercial so need to convert into categorical data type

# %%
bike_data['mnth'] = bike_data['mnth'].astype('category')
bike_data['weekday'] = bike_data['weekday'].astype('category')
bike_data['season'] = bike_data['season'].astype('category')
bike_data['weathersit'] = bike_data['weathersit'].astype('category')
# Out:
# /var/folders/4z/66m_zv7x2xl3dyfdk4h2zzgh0000gn/T/ipykernel_8753/632902885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike_data['mnth'] = bike_data['mnth'].astype('category')
# /var/folders/4z/66m_zv7x2xl3dyfdk4h2zzgh0000gn/T/ipykernel_8753/632902885.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike_data['weekday'] = bike_data['weekday'].astype('category')
# /var/folders/4z/66m_zv7x2xl3dyfdk4h2zzgh0000gn/T/ipykernel_8753/632902885.py:3: SettingWithCopyWarning:
# ...

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    category
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    category
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    category
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    category
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  casual      730 non-null    int64
#  12  registered  730 non-null    int64
#  13  cnt         730 non-null    int64
# dtypes: category(4), float64(4), int64(6)
# memory usage: 66.6 KB

# %% [markdown]
# ### Create a new column for these categorical column

# %%
bike_data = pd.get_dummies(bike_data, drop_first=True)

# %%
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            730 non-null    int64
#  1   holiday       730 non-null    int64
#  2   workingday    730 non-null    int64
#  3   temp          730 non-null    float64
#  4   atemp         730 non-null    float64
#  5   hum           730 non-null    float64
#  6   windspeed     730 non-null    float64
#  7   casual        730 non-null    int64
#  8   registered    730 non-null    int64
#  9   cnt           730 non-null    int64
#  10  season_2      730 non-null    uint8
#  11  season_3      730 non-null    uint8
#  12  season_4      730 non-null    uint8
#  13  mnth_2        730 non-null    uint8
#  14  mnth_3        730 non-null    uint8
#  15  mnth_4        730 non-null    uint8
#  16  mnth_5        730 non-null    uint8
#  17  mnth_6        730 non-null    uint8
# ...

# %%
bike_data.shape
# Out:
# (730, 32)

# %% [markdown]
# # *******************************************************************************************

# %% [markdown]
# ## STEP 4: Model Design

# %% [markdown]
# # ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ### STEP A : SPLIT THE DATA INTO TRAIN AND TEST DATA

# %%
bike_data.shape
# Out:
# (730, 32)

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)

# %%
data_train,data_test = train_test_split(bike_data,train_size=0.70,test_size=0.30,random_state=333)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 483 to 366
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    float64
#  4   atemp         510 non-null    float64
#  5   hum           510 non-null    float64
#  6   windspeed     510 non-null    float64
#  7   casual        510 non-null    int64
#  8   registered    510 non-null    int64
#  9   cnt           510 non-null    int64
#  10  season_2      510 non-null    uint8
#  11  season_3      510 non-null    uint8
#  12  season_4      510 non-null    uint8
#  13  mnth_2        510 non-null    uint8
#  14  mnth_3        510 non-null    uint8
#  15  mnth_4        510 non-null    uint8
#  16  mnth_5        510 non-null    uint8
#  17  mnth_6        510 non-null    uint8
# ...

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 22 to 313
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            219 non-null    int64
#  1   holiday       219 non-null    int64
#  2   workingday    219 non-null    int64
#  3   temp          219 non-null    float64
#  4   atemp         219 non-null    float64
#  5   hum           219 non-null    float64
#  6   windspeed     219 non-null    float64
#  7   casual        219 non-null    int64
#  8   registered    219 non-null    int64
#  9   cnt           219 non-null    int64
#  10  season_2      219 non-null    uint8
#  11  season_3      219 non-null    uint8
#  12  season_4      219 non-null    uint8
#  13  mnth_2        219 non-null    uint8
#  14  mnth_3        219 non-null    uint8
#  15  mnth_4        219 non-null    uint8
#  16  mnth_5        219 non-null    uint8
#  17  mnth_6        219 non-null    uint8
# ...

# %% [markdown]
# # ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ### STEP B: EXPLORATORY DATA ANALYSIS ON TRAINING DATA

# %% [markdown]
# #### CHECKING CATEGORICAL AND NUMERICAL COLUMNS

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 483 to 366
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   yr            510 non-null    int64
#  1   holiday       510 non-null    int64
#  2   workingday    510 non-null    int64
#  3   temp          510 non-null    float64
#  4   atemp         510 non-null    float64
#  5   hum           510 non-null    float64
#  6   windspeed     510 non-null    float64
#  7   casual        510 non-null    int64
#  8   registered    510 non-null    int64
#  9   cnt           510 non-null    int64
#  10  season_2      510 non-null    uint8
#  11  season_3      510 non-null    uint8
#  12  season_4      510 non-null    uint8
#  13  mnth_2        510 non-null    uint8
#  14  mnth_3        510 non-null    uint8
#  15  mnth_4        510 non-null    uint8
#  16  mnth_5        510 non-null    uint8
#  17  mnth_6        510 non-null    uint8
# ...

# %%
data_train.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt', 'season_2', 'season_3', 'season_4',
#        'mnth_2', 'mnth_3', 'mnth_4', 'mnth_5', 'mnth_6', 'mnth_7', 'mnth_8',
#        'mnth_9', 'mnth_10', 'mnth_11', 'mnth_12', 'weekday_1', 'weekday_2',
#        'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6', 'weathersit_2',
#        'weathersit_3'],
#       dtype='object')

# %% [markdown]
# #### ANALYSING THE DATA OF NUMERICAL VALUES temp, atemp,hum,windspeed,cnt

# %%
bike_number = data_train[['temp','atemp','hum','windspeed','cnt']]

# %%
sns.pairplot(bike_number,diag_kind='kde')
plt.show()

# %% [markdown]
# ### Conclusion 5
# #### There is a linear relationship between temp,atemp,cnt

# %% [markdown]
# #### ANALYSING THE DATA OF CATEGORICAL VALUES SEASON, MNTH, WEATHERSIT, HOLIDAY, WEEKDAY, WORKINGDAY against the dependent variable cnt

# %%
bike_day_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 97.0+ KB

# %%
plt.figure(figsize=(25, 10))
plt.subplot(2,3,1)
sns.boxplot( x = 'season', y = 'cnt', data = bike_day_data)
plt.subplot(2,3,2)
sns.boxplot(x = 'mnth', y = 'cnt', data = bike_day_data)
plt.subplot(2,3,3)
sns.boxplot(x = 'weathersit', y ='cnt', data = bike_day_data)
plt.subplot(2,3,4)
sns.boxplot(x = 'holiday', y = 'cnt', data = bike_day_data)
plt.subplot(2,3,5)
sns.boxplot(x = 'weekday', y = 'cnt', data = bike_day_data)
plt.subplot(2,3,6)
sns.boxplot(x = 'workingday', y = 'cnt', data = bike_day_data)
plt.show()

# %% [markdown]
# ### CONCLUSION 6:
# #### Season: Most of the booking happened in the season 3 over median of 5000
# #### mnth: There are more percentage of booking happened in the month 6,7,8,9,10
# #### weathersit: There are more booking happened in the weathersit1
# #### holiday: Most of the booking happened during Holiday
# #### Most of the booking happened during weekday Thursday,Friday, Staurday,Sunday

# %% [markdown]
# ### STEP C: CHECKING THE CORRELATION MATRIX

# %%
plt.figure(figsize = (25,20))
sns.heatmap(bike_data.corr(),annot=True,cmap='RdBu')
plt.show()

# %% [markdown]
# ### STPE D: RESCALING

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
data_train.head()
# Out:
#      yr  holiday  workingday       temp     atemp      hum  windspeed  casual  \
# 483   1        0           0  18.791653  22.50605  58.7083   7.832836    2229
# 650   1        0           0  16.126653  19.56980  49.4583   9.791514    2252
# 212   0        0           1  31.638347  35.16460  55.0833  10.500039     729
# 714   1        0           0  14.862500  18.49690  83.8750   6.749714     538
# 8     0        0           0   5.671653   5.80875  43.4167  24.250650      54
#
#      registered   cnt  ...  mnth_11  mnth_12  weekday_1  weekday_2  weekday_3  \
# 483        4075  6304  ...        0        0          0          0          0
# 650        4857  7109  ...        0        0          0          0          0
# 212        3537  4266  ...        0        0          1          0          0
# 714        3248  3786  ...        0        1          0          0          0
# 8           768   822  ...        0        0          0          0          0
#
# ...

# %%
data_train[['temp','atemp','hum','windspeed','cnt']] = scaler.fit_transform(data_train[['temp','atemp','hum','windspeed','cnt']])

# %%
data_train.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  casual  \
# 483   1        0           0  0.497426  0.487055  0.609956   0.194850    2229
# 650   1        0           0  0.416433  0.409971  0.513852   0.255118    2252
# 212   0        0           1  0.887856  0.819376  0.572294   0.276919     729
# 714   1        0           0  0.378013  0.381804  0.871429   0.161523     538
# 8     0        0           0  0.098690  0.048706  0.451083   0.700017      54
#
#      registered       cnt  ...  mnth_11  mnth_12  weekday_1  weekday_2  \
# 483        4075  0.722734  ...        0        0          0          0
# 650        4857  0.815347  ...        0        0          0          0
# 212        3537  0.488265  ...        0        0          1          0
# 714        3248  0.433042  ...        0        1          0          0
# 8           768  0.092039  ...        0        0          0          0
#
# ...

# %% [markdown]
# # ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## STEP 5: BUILDING A LINEAR MODEL

# %% [markdown]
# ### Y : DEPENDENT VARIABLE "cnt"
# ### X : INDEPENDENT VARIABLE

# %%
Y_bike_train = data_train.pop('cnt')
X_bike_train = data_train
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cnt'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #### Import Linear Regression Libraries

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_bike_train,Y_bike_train)

rfe = RFE(lm,n_features_to_select=15)
rfe = rfe.fit(X_bike_train,Y_bike_train)

# %%
list(zip(X_bike_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', True, 1),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('casual', True, 1),
#  ('registered', True, 1),
#  ('season_2', False, 3),
#  ('season_3', False, 2),
#  ('season_4', True, 1),
#  ('mnth_2', True, 1),
#  ('mnth_3', False, 5),
#  ('mnth_4', True, 1),
#  ('mnth_5', False, 15),
#  ('mnth_6', False, 12),
#  ('mnth_7', False, 16),
#  ('mnth_8', False, 9),
#  ('mnth_9', False, 13),
#  ('mnth_10', False, 8),
#  ('mnth_11', False, 4),
#  ('mnth_12', True, 1),
#  ('weekday_1', False, 14),
#  ('weekday_2', True, 1),
#  ('weekday_3', False, 6),
#  ('weekday_4', False, 10),
#  ('weekday_5', False, 17),
#  ('weekday_6', False, 7),
#  ('weathersit_2', False, 11),
#  ('weathersit_3', True, 1)]

# %%
column = X_bike_train.columns[rfe.support_]
column
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'season_4', 'mnth_2', 'mnth_4', 'mnth_12',
#        'weekday_2', 'weathersit_3'],
#       dtype='object')

# %%
X_bike_train.columns[~rfe.support_]
# Out:
# Index(['season_2', 'season_3', 'mnth_3', 'mnth_5', 'mnth_6', 'mnth_7',
#        'mnth_8', 'mnth_9', 'mnth_10', 'mnth_11', 'weekday_1', 'weekday_3',
#        'weekday_4', 'weekday_5', 'weekday_6', 'weathersit_2'],
#       dtype='object')

# %%
X_bike_train_rfe = X_bike_train[column]

# %% [markdown]
# ## MODEL 1

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X_bike_train_rfe.columns
vif['VIF'] = [variance_inflation_factor(X_bike_train_rfe.values, i) for i in range(X_bike_train_rfe.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#         Features     VIF
# 3           temp  359.63
# 4          atemp  357.75
# 8     registered   36.92
# 5            hum   12.68
# 2     workingday    9.08
# 7         casual    8.03
# 0             yr    5.20
# 6      windspeed    4.69
# 9       season_4    2.17
# 10        mnth_2    1.30
# 12       mnth_12    1.28
# 13     weekday_2    1.27
# 14  weathersit_3    1.27
# 11        mnth_4    1.26
# 1        holiday    1.09

# %%
import statsmodels.api as sm
X_bike_train_lm1 = sm.add_constant(X_bike_train_rfe)

lr1 = sm.OLS(Y_bike_train, X_bike_train_lm1).fit()

# %%
lr1.params
# Out:
# const          -2.531063e-03
# yr             -6.071532e-17
# holiday         3.573530e-16
# workingday      2.941440e-16
# temp            8.014422e-16
# atemp          -1.082467e-15
# hum             1.214306e-16
# windspeed      -7.415943e-17
# casual          1.150483e-04
# registered      1.150483e-04
# season_4        6.331741e-17
# mnth_2          4.683753e-17
# mnth_4          7.589415e-17
# mnth_12        -6.591949e-17
# weekday_2      -7.285839e-17
# weathersit_3   -5.421011e-17
# dtype: float64

# %%
print(lr1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.756e+30
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:14:28   Log-Likelihood:                 17285.
# No. Observations:                 510   AIC:                        -3.454e+04
# Df Residuals:                     494   BIC:                        -3.447e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.0025   1.55e-16  -1.63e+13      0.000      -0.003      -0.003
# ...

# %% [markdown]
# ### MODEL 2
# #### Removing the variable 'atemp' based on its High p-value and High VIF

# %%
X_bike_train_2 = X_bike_train_rfe.drop(['atemp'],axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X_bike_train_2.columns
vif['VIF'] = [variance_inflation_factor(X_bike_train_2.values, i) for i in range(X_bike_train_2.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#         Features    VIF
# 7     registered  36.86
# 3           temp  22.42
# 4            hum  12.44
# 2     workingday   9.08
# 6         casual   8.02
# 0             yr   5.20
# 5      windspeed   4.55
# 8       season_4   2.15
# 9         mnth_2   1.29
# 11       mnth_12   1.28
# 12     weekday_2   1.27
# 13  weathersit_3   1.27
# 10        mnth_4   1.24
# 1        holiday   1.09

# %%
X_bike_train_lm2 = sm.add_constant(X_bike_train_2)

lr2 = sm.OLS(Y_bike_train, X_bike_train_lm2).fit()

# %%
lr2.params
# Out:
# const          -2.531063e-03
# yr             -1.734723e-17
# holiday         2.879641e-16
# workingday      3.707971e-17
# temp           -3.226586e-16
# hum             2.732189e-17
# windspeed       1.546072e-16
# casual          1.150483e-04
# registered      1.150483e-04
# season_4       -1.092876e-16
# mnth_2          5.204170e-18
# mnth_4         -9.931292e-17
# mnth_12        -1.474515e-17
# weekday_2      -1.379105e-16
# weathersit_3   -2.428613e-17
# dtype: float64

# %%
lr2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.423e+31
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:22:58   Log-Likelihood:                 17422.
# No. Observations:                 510   AIC:                        -3.481e+04
# Df Residuals:                     495   BIC:                        -3.475e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Removing the variable 'hum' on its high VIF value

# %%
X_bike_train_3 = X_bike_train_2.drop(["hum"], axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X_bike_train_3.columns
vif['VIF'] = [variance_inflation_factor(X_bike_train_3.values, i) for i in range(X_bike_train_3.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
#         Features    VIF
# 6     registered  35.98
# 3           temp  17.95
# 2     workingday   8.33
# 5         casual   7.83
# 0             yr   5.15
# 4      windspeed   4.24
# 7       season_4   1.87
# 11     weekday_2   1.27
# 12  weathersit_3   1.25
# 9         mnth_4   1.23
# 8         mnth_2   1.22
# 10       mnth_12   1.19
# 1        holiday   1.09

# %%
X_bike_train_lm3 = sm.add_constant(X_bike_train_3)

lr3 = sm.OLS(Y_bike_train, X_bike_train_lm3).fit()

# %%
lr3.params
# Out:
# const          -2.531063e-03
# yr             -2.905662e-16
# holiday         2.636780e-16
# workingday      6.526897e-17
# temp           -6.938894e-17
# windspeed      -4.033232e-17
# casual          1.150483e-04
# registered      1.150483e-04
# season_4        2.602085e-18
# mnth_2          7.719519e-17
# mnth_4          3.556183e-17
# mnth_12        -6.288373e-17
# weekday_2       8.239937e-17
# weathersit_3   -1.127570e-16
# dtype: float64

# %%
lr3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.575e+28
# Date:                Tue, 12 Sep 2023   Prob (F-statistic):               0.00
# Time:                        15:27:07   Log-Likelihood:                 15792.
# No. Observations:                 510   AIC:                        -3.156e+04
# Df Residuals:                     496   BIC:                        -3.150e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
X_bike_train_4 = X_bike_train_3.drop(['season3'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 X_bike_train_4 = X_bike_train_3.drop(['season3'],axis=1)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X_bike_train_4.columns
vif['VIF'] = [variance_inflation_factor(X_bike_train_4.values, i) for i in range(X_bike_train_4.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 3
#       1 from statsmodels.stats.outliers_influence import variance_inflation_factor
#       2 vif = pd.DataFrame()
# ----> 3 vif['Features'] = X_bike_train_4.columns
#       4 vif['VIF'] = [variance_inflation_factor(X_bike_train_4.values, i) for i in range(X_bike_train_4.shape[1])]
#       5 vif['VIF'] = round(vif['VIF'],2)
#
# NameError: name 'X_bike_train_4' is not defined

# %%
X_bike_train_lm4 = sm.add_constant(X_bike_train_4)

lr4 = sm.OLS(Y_bike_train, X_bike_train_lm4).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 X_bike_train_lm4 = sm.add_constant(X_bike_train_4)
#       3 lr4 = sm.OLS(Y_bike_train, X_bike_train_lm4).fit()
#
# NameError: name 'X_bike_train_4' is not defined

# %%
lr4.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 lr4.params
#
# NameError: name 'lr4' is not defined

# %%
lr4.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 lr4.summary()
#
# NameError: name 'lr4' is not defined

# %%
X_bike_train_5 = X_bike_train_4.drop(['mnth_10'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 X_bike_train_5 = X_bike_train_4.drop(['mnth_10'],axis=1)
#
# NameError: name 'X_bike_train_4' is not defined

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X_bike_train_5.columns
vif['VIF'] = [variance_inflation_factor(X_bike_train_5.values, i) for i in range(X_bike_train_5.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 3
#       1 from statsmodels.stats.outliers_influence import variance_inflation_factor
#       2 vif = pd.DataFrame()
# ----> 3 vif['Features'] = X_bike_train_5.columns
#       4 vif['VIF'] = [variance_inflation_factor(X_bike_train_5.values, i) for i in range(X_bike_train_5.shape[1])]
#       5 vif['VIF'] = round(vif['VIF'],2)
#
# NameError: name 'X_bike_train_5' is not defined

# %%
X_bike_train_lm5 = sm.add_constant(X_bike_train_5)

lr5 = sm.OLS(Y_bike_train, X_bike_train_lm5).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 X_bike_train_lm5 = sm.add_constant(X_bike_train_5)
#       3 lr5 = sm.OLS(Y_bike_train, X_bike_train_lm5).fit()
#
# NameError: name 'X_bike_train_5' is not defined

# %%
lr5.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 lr5.params
#
# NameError: name 'lr5' is not defined

# %%
lr5.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 lr5.summary()
#
# NameError: name 'lr5' is not defined

# %% [markdown]
# ### Removing the variable mnth3 based on high p-value

# %%
X_bike_train_6 = X_bike_train_5.drop(['mnth_3'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 X_bike_train_6 = X_bike_train_5.drop(['mnth_3'], axis = 1)
#
# NameError: name 'X_bike_train_5' is not defined

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X_bike_train_6.columns
vif['VIF'] = [variance_inflation_factor(X_bike_train_6.values, i) for i in range(X_bike_train_6.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[137], line 3
#       1 from statsmodels.stats.outliers_influence import variance_inflation_factor
#       2 vif = pd.DataFrame()
# ----> 3 vif['Features'] = X_bike_train_6.columns
#       4 vif['VIF'] = [variance_inflation_factor(X_bike_train_6.values, i) for i in range(X_bike_train_6.shape[1])]
#       5 vif['VIF'] = round(vif['VIF'],2)
#
# NameError: name 'X_bike_train_6' is not defined

# %%
X_bike_train_lm6 = sm.add_constant(X_bike_train_6)

lr6 = sm.OLS(Y_bike_train, X_bike_train_lm6).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 X_bike_train_lm6 = sm.add_constant(X_bike_train_6)
#       3 lr6 = sm.OLS(Y_bike_train, X_bike_train_lm6).fit()
#
# NameError: name 'X_bike_train_6' is not defined

# %%
lr6.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 lr6.params
#
# NameError: name 'lr6' is not defined

# %%
lr6.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 lr6.summary()
#
# NameError: name 'lr6' is not defined

# %% [markdown]
# ### CONCLUSION 7
# #### The data has low multicollinearity. We will consider this as our final model

# %% [markdown]
# ## *********************************************************************************************************

# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# ### H0: B1 = B2 = ...Bn =0
# ### H1: at leat one Bi!=0

# %% [markdown]
# ### Linear Regression Model 6 coefficient Values
# #### 1) const 0.084143
# #### 2) yr 0.230846
# #### 3) workingday 0.043203
# #### 4) temp 0.563615
# #### 5) windspeed -0.155191
# #### 6) season_2 0.082706
# #### 7) season_4 0.128744
# #### 8) mnth_9 0.094743
# #### 9) weekday_6 0.056909
# #### 10) weathersit_2 -0.074807
# #### 11) weathersit_3 -0.306992

# %% [markdown]
# # The above coefficients are not equal to zero so we can reject the NULL HYPOTHESIS

# %% [markdown]
# # F Satistics
# #### F-Statistics is used for testing the overall significance of the model
#
# F-statics: 233.8
# Prob:3.77e-181
#
# # The model is significant

# %% [markdown]
# # **********************************************************************************

# %% [markdown]
# # RESIDUAL ANALYSIS OF TRAINING DATA

# %%
Y_bike_train_pred = lr6.predict(X_train_lm6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 Y_bike_train_pred = lr6.predict(X_train_lm6)
#
# NameError: name 'lr6' is not defined

# %%
res = Y_bike_train_pred
fig = plt.figure()
sns.displot((res),bins=20)
fig.suptitle("Error Terms",fontsize =20)
plt.xlabel('Error',fontsize =18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 res = Y_bike_train_pred
#       2 fig = plt.figure()
#       3 sns.displot((res),bins=20)
#
# NameError: name 'Y_bike_train_pred' is not defined

# %% [markdown]
# ### CONCLUSION 8
# #### Residuals are normally distributed

# %%
bike_data_new = bike_data[['temp','atemp','hum','windspeed','cnt']]
sns.pairplot(bike_data_new,diag_kind='kde')
plt.show()

# %% [markdown]
# ### CONCLUSION 10
# #### There is a linear relation between temp,atemp with the dependent variable 'cnt'

# %% [markdown]
# ### There is no multicollinearity between the dependent variables

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = X_bike_train_6.columns
vif['VIF'] = [variance_inflation_factor(X_bike_train_6.values, i) for i in range(X_bike_train_6.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by='VIF', ascending = False)
vif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 3
#       1 from statsmodels.stats.outliers_influence import variance_inflation_factor
#       2 vif = pd.DataFrame()
# ----> 3 vif['Features'] = X_bike_train_6.columns
#       4 vif['VIF'] = [variance_inflation_factor(X_bike_train_6.values, i) for i in range(X_bike_train_6.shape[1])]
#       5 vif['VIF'] = round(vif['VIF'],2)
#
# NameError: name 'X_bike_train_6' is not defined

# %% [markdown]
# # PREDICTION ON FINAL MODEL

# %%
num = ['temp','atemp','hum','windspeed','cnt']
data_test[num] = scaler.transform(data_test[num])

# %%
data_test.head()
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  casual  \
# 22    0        0           0  0.046591  0.025950  0.453529   0.462217     150
# 468   1        0           0  0.543115  0.536771  0.522511   0.347424    2795
# 553   1        0           0  0.951196  0.933712  0.596104   0.212829    1203
# 504   1        0           0  0.699909  0.662746  0.551083   0.478229    2704
# 353   0        0           1  0.407087  0.416610  0.618615   0.080770     216
#
#      registered       cnt  ...  mnth_11  mnth_12  weekday_1  weekday_2  \
# 22          836  0.110907  ...        0        0          0          0
# 468        4665  0.855729  ...        0        0          0          0
# 553        3469  0.534975  ...        0        0          0          0
# 504        4425  0.817648  ...        0        0          0          0
# 353        3534  0.428900  ...        0        1          0          1
#
# ...

# %%
data_test.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.493151    0.041096    0.684932    0.551225    0.527528    0.662567
# std      0.501098    0.198967    0.465607    0.229463    0.215434    0.143562
# min      0.000000    0.000000    0.000000    0.046591    0.025950    0.301299
# 25%      0.000000    0.000000    0.000000    0.356479    0.348019    0.553031
# 50%      0.000000    0.000000    1.000000    0.557653    0.549198    0.662338
# 75%      1.000000    0.000000    1.000000    0.751309    0.709163    0.762338
# max      1.000000    1.000000    1.000000    0.984424    0.980934    1.010390
#
#         windspeed       casual   registered         cnt  ...     mnth_11  \
# count  219.000000   219.000000   219.000000  219.000000  ...  219.000000
# mean     0.346706   842.105023  3690.077626    0.518889  ...    0.073059
# ...

# %%
Y_bike_test = data_test.pop('cnt')
X_bike_test = data_test

# %%
col1 =X_bike_train.columns
X_bike_test = X_bike_test[col1]
X_bike_test_lm6 = sm.add_constant(X_bike_test)
X_bike_test_lm6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 22 to 313
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   const         219 non-null    float64
#  1   yr            219 non-null    int64
#  2   holiday       219 non-null    int64
#  3   workingday    219 non-null    int64
#  4   temp          219 non-null    float64
#  5   atemp         219 non-null    float64
#  6   hum           219 non-null    float64
#  7   windspeed     219 non-null    float64
#  8   casual        219 non-null    int64
#  9   registered    219 non-null    int64
#  10  season_2      219 non-null    uint8
#  11  season_3      219 non-null    uint8
#  12  season_4      219 non-null    uint8
#  13  mnth_2        219 non-null    uint8
#  14  mnth_3        219 non-null    uint8
#  15  mnth_4        219 non-null    uint8
#  16  mnth_5        219 non-null    uint8
#  17  mnth_6        219 non-null    uint8
# ...

# %%
Y_pred = lm6.predict(X_bike_test_lm6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 Y_pred = lm6.predict(X_bike_test_lm6)
#
# NameError: name 'lm6' is not defined

# %% [markdown]
# # Model Evaluation

# %%
fig  = plt.figure()
plt.scatter(Y_bike_test,Y_pred,aplha=.5)
fig.suptitle('y_test vs Y_pred',fontsize =20)
plt.xlabel('y_test',fontsize=18)
plt.ylabel('y_pred',fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 2
#       1 fig  = plt.figure()
# ----> 2 plt.scatter(Y_bike_test,Y_pred,aplha=.5)
#       3 fig.suptitle('y_test vs Y_pred',fontsize =20)
#       4 plt.xlabel('y_test',fontsize=18)
#
# NameError: name 'Y_pred' is not defined

# %% [markdown]
# # R^2 Value for Test

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[158], line 2
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score(y_test,y_pred)
#
# NameError: name 'y_test' is not defined
